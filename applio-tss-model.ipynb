# %% [markdown]
# <h1 style="color:#2bb2c0; text-align:center;">🎉Добро пожаловать в блокнот The Angel Studio!🎉</h1>
# <h3 style="color:#32CD32; text-align:center;">Первая яцейка Устанавливает Applio-Делается один раз!</h3>

# %%
import os

from IPython.display import clear_output, display, HTML
# Статусы вывода
def print_status(message):
    display(HTML(f"<h2 style='color: green;'>✅ {message}</h2>"))
def print_warning(message):
    display(HTML(f"<h2 style='color: orange;'>⚠️ {message}</h2>"))
def print_error(message):
    display(HTML(f"<h2 style='color: red;'>❌ {message}</h2>"))
    
print_status("Начинаю Установку Applio-Делается один раз!...")

# %cd /content
# !git clone https://github.com/harry2141985/Applio.git
# %cd Applio
#Установка зависимостей
# !pip install torch torchaudio torchvision --index-url https://download.pytorch.org/whl/cu128
# !pip install -r requirements.txt
# !apt-get install -y portaudio19-dev
# !pip install sounddevice

clear_output()
print_status("Установка успешна завершина можно запускать приложение....")
# Out:
# <h2 style='color: green;'>✅ Установка успешна завершина можно запускать приложение....</h2>

# %% [markdown]
# <h1 style="color:#32CD32; text-align:center;">Запуска Applio</h1>

# %%
# !python app.py
# Out:
# ...
# An error occurred connecting to Discord: Could not find Discord installed and running on this machine.
# * Running on local URL:  http://127.0.0.1:6969
# * Running on public URL: https://1363f06cf32c73331d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# An error occurred connecting to Discord: Could not find Discord installed and running on this machine.
# * Running on local URL:  http://127.0.0.1:6969
# * Running on public URL: https://e9827818b62605c828.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Model author set to The Angel Studio.
# Precision set to fp32.
# Precision set to fp32.
# Starting preprocess with 4 processes...
# ...
